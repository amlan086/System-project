# %%
cd C:\\Users\\ASUS\\Desktop\\violence_detection
# Out:
# C:\Users\ASUS\Desktop\violence_detection

# %%
import cv2
import numpy as np
import os
import math
import numpy as np
from PIL import Image
width = 128
height =64
dim = (width, height)

for frm_no in range(1,101):
    dr='./movie fight/Peliculas/noFights/'+str(frm_no)+'.mpg'
    cap = cv2.VideoCapture(dr)
    fl='ndata_'+str(frm_no)
    try:
        if not os.path.exists(fl):
            os.makedirs(fl)
    except OSError:
        print ('Error: Creating directory of data')

    currentFrame = 0
    while(cap.isOpened()):
        ret, frm = cap.read()
        
        if ret == True:
            frame = cv2.resize(frm, dim, interpolation = cv2.INTER_AREA)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            ret,thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
            name = './'+fl+'/frame' + str(currentFrame) + '.jpg'
            #print ('Creating...' + name)
            cv2.imwrite(name, thresh)


            currentFrame += 1
        else:
            break

    cap.release()
    cv2.destroyAllWindows()

for frm_no in range(1,101):
    dr='./movie fight/Peliculas/fights/newfi'+str(frm_no)+'.avi'
    cap = cv2.VideoCapture(dr)
    fl='data_'+str(frm_no)
    try:
        if not os.path.exists(fl):
            os.makedirs(fl)
    except OSError:
        print ('Error: Creating directory of data')

    currentFrame = 0
    while(cap.isOpened()):
        ret, frm = cap.read()
        
        if ret == True:
            frame = cv2.resize(frm, dim, interpolation = cv2.INTER_AREA)
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            ret,thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
            name = './'+fl+'/frame' + str(currentFrame) + '.jpg'
            #print ('Creating...' + name)
            cv2.imwrite(name, thresh)


            currentFrame += 1
        else:
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
import math
import numpy as np
from PIL import Image
import os
import random
import cv2
X=[]
y=[]
for z in range(1,101):
    print(z)
    if z>=0:
        #com_list=[]
        
        ss='C:\\Users\\Asus\\Desktop\\violence_detection\\bin_fight\\data_'+str(z)
        os.chdir(ss)
        
        file_list = os.listdir(ss) 
        number_of_files = len(file_list)
        #print(str(z) + " --- "+str(number_of_files))
        #lst=random.sample(range(1,number_of_files), 31)
        #lst.sort()


        for x in range(1,2):
            res=[]
            #print(x)
            s='frame'+str(x)+'.jpg'
          
            #print(s)
            #print(number_of_files)
            gray=cv2.imread(s)
            
            cell_size=(8,8)
            block_size=(2,2)
            nbins=9


            winSize = (gray.shape[1] // cell_size[1] * cell_size[1],gray.shape[0] // cell_size[0] * cell_size[0])
            blockSize = (block_size[1] * cell_size[1],block_size[0] * cell_size[0])
            blockStride = (cell_size[1], cell_size[0])
            cellSize = (cell_size[1], cell_size[0])
            nbins = 9
            derivAperture = 1
            winSigma = -1.
            histogramNormType = 0
            L2HysThreshold = 0.2
            gammaCorrection = 1
            nlevels = 64
            signedGradients = True
 
            hog = cv2.HOGDescriptor(winSize,blockSize,blockStride,cellSize,nbins,derivAperture,winSigma,histogramNormType,L2HysThreshold,gammaCorrection,nlevels, signedGradients)

            n_cells = (gray.shape[0] // cell_size[0], gray.shape[1] // cell_size[1])
            hog_feats = hog.compute(gray).ravel()
            hog_lst=hog_feats.tolist()
            print(hog_lst)
            name = 'C:\\Users\\Asus\\Desktop\\violence_detection\\' + str(x) + 'f.jpg'
            img = Image.new( 'L', (128,64), "black")
            pixels = img.load()
            k=0
            for j in range(img.size[1]):
                for i in range(img.size[0]):
                    pixels[i,j] =hog_lst[k]
                    k=k+1
                
            
            img.save(name)
            X.append(hog_lst)
            y.append(1)
for z in range(1,2):
    print(z)
    if z>=0:
        #com_list=[]
        
        ss='C:\\Users\\Asus\\Desktop\\violence_detection\\bin_nfight\\ndata_'+str(z)
        os.chdir(ss)
        
        file_list = os.listdir(ss) 
        number_of_files = len(file_list)
        #print(str(z) + " --- "+str(number_of_files))
        #lst=random.sample(range(1,number_of_files), 31)
        #lst.sort()


        for x in range(1,number_of_files):
            res=[]
            print(number_of_files)
            s='frame'+str(x)+'.jpg'
            #print(s)
            gray=cv2.imread(s)
            
            cell_size=(8,8)
            block_size=(2,2)
            nbins=9


            winSize = (gray.shape[1] // cell_size[1] * cell_size[1],gray.shape[0] // cell_size[0] * cell_size[0])
            blockSize = (block_size[1] * cell_size[1],block_size[0] * cell_size[0])
            blockStride = (cell_size[1], cell_size[0])
            cellSize = (cell_size[1], cell_size[0])
            nbins = 9
            derivAperture = 1
            winSigma = -1.
            histogramNormType = 0
            L2HysThreshold = 0.2
            gammaCorrection = 1
            nlevels = 64
            signedGradients = True
 
            hog = cv2.HOGDescriptor(winSize,blockSize,blockStride,cellSize,nbins,derivAperture,winSigma,histogramNormType,L2HysThreshold,gammaCorrection,nlevels, signedGradients)

            n_cells = (gray.shape[0] // cell_size[0], gray.shape[1] // cell_size[1])
            hog_feats = hog.compute(gray).ravel()
            hog_lst=hog_feats.tolist()
            hog_lst[0].shape
            name = 'C:\\Users\\Asus\\Desktop\\violence_detection\\' + str(x) + 'n.jpg'
            #cv2.destroyAllWindows()
            img = Image.new( 'L', (128,64), "black")
            pixels = img.load()
            k=0
            for j in range(img.size[1]):
                for i in range(img.size[0]):
                    pixels[i,j] =hog_lst[k]
                    k=k+1
                
            
            img.save(name)
            cv2.destroyAllWindows()
            X.append(hog_lst)
            y.append(0)
# Out:
# 1
# [0.18784917891025543, 0.21633656322956085, 0.21408717334270477, 0.008837148547172546, 0.21749503910541534, 0.1519235223531723, 0.2014111876487732, 0.0668591782450676, 0.0707097128033638, 0.11302553117275238, 0.10490866750478745, 0.08598116785287857, 0.006876936182379723, 0.1624687761068344, 0.10778583586215973, 0.22008097171783447, 0.09297385811805725, 0.07483235746622086, 0.22008097171783447, 0.18920782208442688, 0.22008097171783447, 0.12627428770065308, 0.19113518297672272, 0.1980004757642746, 0.0944463387131691, 0.12541504204273224, 0.22008097171783447, 0.22008097171783447, 0.22008097171783447, 0.08886571228504181, 0.040138859301805496, 0.20801033079624176, 0.21263107657432556, 0.18985335528850555, 0.2017110139131546, 0.22008097171783447, 0.030132940039038658, 0.12138881534337997, 0.29021456837654114, 0.003498815931379795, 0.03446167707443237, 0.013784045353531837, 0.13050371408462524, 0.05915531516075134, 0.03714193031191826, 0.05754425376653671, 0.19736063480377197, 0.29021456837654114, 0.01163502223789692, 0.013933537527918816, 0.0031839022412896156, 0.29021456837654114, 0.21471478044986725, 0.06367138773202896, 0.13744939863681793, 0.2501591742038727, 0.29021456837654114, 0.0054521397687494755, 0.08348079025745392, 0.07809721678495407, 0.17093132436275482, 0.15036487579345703, 0.1456582397222519, 0.20065483450889587, 0.2684575021266937, 0.29021456837654114, 0.006814529653638601, 0.036401644349098206, 0.017974214628338814, 0.29021456837654114, 0.19411905109882355, 0.201814666390419, 0.09327300637960434, 0.07579223066568375, 0.172395259141922, 0.038658831268548965, 0.022689856588840485, 0.0005087655736133456, 0.2825898826122284, 0.18188254535198212, 0.10690271109342575, 0.06245578080415726, 0.06497650593519211, 0.13665452599525452, 0.05357429385185242, 0.05284449830651283, 0.020531924441456795, 0.052449505776166916, 0.04496495798230171, 0.07755742222070694, 0.2825898826122284, 0.16056230664253235, 0.2261773645877838, 0.016198910772800446, 0.075690358877182, 0.0006568956887349486, 0.2825898826122284, 0.24681657552719116, 0.2825898826122284, 0.2825898826122284, 0.10333714634180069, 0.2825898826122284, 0.0207955501973629, 0.11632046103477478, 0.015636304393410683, 0.2825898826122284, 0.2350197285413742, 0.2825898826122284, 0.03834349289536476, 0.11307939887046814, 0.2590898275375366, 0.0960521548986435, 0.022993043065071106, 0.01456125546246767, 0.1559199094772339, 0.09328866750001907, 0.05585930868983269, 0.09131275117397308, 0.19654999673366547, 0.2886543571949005, 0.07958818227052689, 0.02348838932812214, 0.006285147741436958, 0.2886543571949005, 0.18018898367881775, 0.12086702138185501, 0.09907963871955872, 0.17388319969177246, 0.2886543571949005, 0.017213964834809303, 0.04380721598863602, 0.010607009753584862, 0.2886543571949005, 0.1597103625535965, 0.1447550654411316, 0.02392897941172123, 0.2739850878715515, 0.2886543571949005, 0.060360051691532135, 0.10395948588848114, 0.0066788154654204845, 0.2886543571949005, 0.28310322761535645, 0.09800422191619873, 0.27400705218315125, 0.27400705218315125, 0.27400705218315125, 0.012887101620435715, 0.030686600133776665, 0.0036785274278372526, 0.11305741965770721, 0.06611313670873642, 0.2290746420621872, 0.27400705218315125, 0.1668650507926941, 0.22523163259029388, 0.003283135825768113, 0.01599980890750885, 0.0003821623686235398, 0.005021576303988695, 0.004877213388681412, 0.24332337081432343, 0.0445704311132431, 0.2602115571498871, 0.27400705218315125, 0.18512535095214844, 0.27400705218315125, 0.0126987025141716, 0.22613151371479034, 0.1065588966012001, 0.05567682534456253, 0.028188634663820267, 0.09725755453109741, 0.27400705218315125, 0.11065195500850677, 0.2646389305591583, 0.008087151683866978, 0.003530736081302166, 0.0021966753993183374, 0.02290545217692852, 0.27815675735473633, 0.04030081257224083, 0.054496582597494125, 0.0008201909950003028, 0.005858093965798616, 0.0013340109726414084, 0.15155166387557983, 0.0641283392906189, 0.2739575207233429, 0.25947171449661255, 0.21342 ...
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-30-4fd0039139c9> in <module>()
#      61             for j in range(img.size[1]):
#      62                 for i in range(img.size[0]):
# ---> 63                     pixels[i,j] =hog_lst[k]
#      64                     k=k+1
#      65
#
# SystemError: new style getargs format but argument is not a tuple

# %%
import math
import numpy as np
from PIL import Image
import os
import random
import cv2
acc=0
tot=0
for z in range(1,101):
    print(z)
    if z%5==0:
        tot=tot+1
        #com_list=[]
        
        ss='C:\\Users\\ASUS\\Desktop\\violence_detection\\bin_f\\data_'+str(z)
        os.chdir(ss)
        
        file_list = os.listdir(ss) 
        number_of_files = len(file_list)
        #print(str(z) + " --- "+str(number_of_files))
        #lst=random.sample(range(1,number_of_files), 31)
        #lst.sort()

        cnt=0
        for x in range(1,number_of_files+1):
            res=[]
            #print(x)
            s='frame'+str(x)+'.jpg'
            #print(s)
            gray=cv2.imread(s)
            
            cell_size=(8,8)
            block_size=(2,2)
            nbins=9


            winSize = (gray.shape[1] // cell_size[1] * cell_size[1],gray.shape[0] // cell_size[0] * cell_size[0])
            blockSize = (block_size[1] * cell_size[1],block_size[0] * cell_size[0])
            blockStride = (cell_size[1], cell_size[0])
            cellSize = (cell_size[1], cell_size[0])
            nbins = 9
            derivAperture = 1
            winSigma = -1.
            histogramNormType = 0
            L2HysThreshold = 0.2
            gammaCorrection = 1
            nlevels = 64
            signedGradients = True
 
            hog = cv2.HOGDescriptor(winSize,blockSize,blockStride,cellSize,nbins,derivAperture,winSigma,histogramNormType,L2HysThreshold,gammaCorrection,nlevels, signedGradients)

            n_cells = (gray.shape[0] // cell_size[0], gray.shape[1] // cell_size[1])
            hog_feats = hog.compute(gray).ravel()
            hog_lst=hog_feats.tolist()
            rs=clf.predict([hog_lst])
            
            if rs[0]==1:
                cnt=cnt+1;
                    #print(cnt)
        #print(cnt)
        if cnt>(number_of_files/2):
            acc=acc+1
            print("fight")
        else:
            print("non fight")

            

for z in range(1,101):
    print(z)
    if z%5==0:
        tot=tot+1
        #com_list=[]
        
        ss='C:\\Users\\ASUS\\Desktop\\violence_detection\\bin_nf\\ndata_'+str(z)
        os.chdir(ss)
        
        file_list = os.listdir(ss) 
        number_of_files = len(file_list)
        #print(str(z) + " --- "+str(number_of_files))
        #lst=random.sample(range(1,number_of_files), 31)
        #lst.sort()

        cnt=0
        for x in range(1,number_of_files+1):
            res=[]
            #print(x)
            s='frame'+str(x)+'.jpg'
            #print(s)
            gray=cv2.imread(s)
            
            cell_size=(8,8)
            block_size=(2,2)
            nbins=9


            winSize = (gray.shape[1] // cell_size[1] * cell_size[1],gray.shape[0] // cell_size[0] * cell_size[0])
            blockSize = (block_size[1] * cell_size[1],block_size[0] * cell_size[0])
            blockStride = (cell_size[1], cell_size[0])
            cellSize = (cell_size[1], cell_size[0])
            nbins = 9
            derivAperture = 1
            winSigma = -1.
            histogramNormType = 0
            L2HysThreshold = 0.2
            gammaCorrection = 1
            nlevels = 64
            signedGradients = True
 
            hog = cv2.HOGDescriptor(winSize,blockSize,blockStride,cellSize,nbins,derivAperture,winSigma,histogramNormType,L2HysThreshold,gammaCorrection,nlevels, signedGradients)

            n_cells = (gray.shape[0] // cell_size[0], gray.shape[1] // cell_size[1])
            hog_feats = hog.compute(gray).ravel()
            hog_lst=hog_feats.tolist()
            rs=clf.predict([hog_lst])
            if rs[0]==1:
                cnt=cnt+1;
                    #print(cnt)
        #print(cnt)
        if cnt>(number_of_files/2):
            print("fight")
        else:
            acc=acc+1
            print("non fight")

acuracy=(acc/tot)*100
print(acuracy)
# Out:
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-fde7b5720fbf> in <module>()
#      53             hog_feats = hog.compute(gray).ravel()
#      54             hog_lst=hog_feats.tolist()
# ---> 55             rs=clf.predict([hog_lst])
#      56
#      57             if rs[0]==1:
#
# AttributeError: 'int' object has no attribute 'predict'

# %%
c =list( zip(X,y))
random.shuffle(c)
X = [i[0] for i in c]
y = [i[1] for i in c]

# %%
from tkinter import *
from tkinter import filedialog
import math
import numpy as np
from PIL import Image
from sklearn import svm
import os
import random
import cv2
root = Tk()
X=[]
y=[]
clf=0
print('Videos are processing!')
for z in range(1,101):
    #print(z)
    if z%3!=0:
            #com_list=[]

        ss='C:\\Users\\ASUS\\Desktop\\violence_detection\\bin_f\\data_'+str(z)
        os.chdir(ss)

        file_list = os.listdir(ss) 
        number_of_files = len(file_list)
            #print(str(z) + " --- "+str(number_of_files))
            #lst=random.sample(range(1,number_of_files), 31)
            #lst.sort()


        for x in range(1,number_of_files+1):
            res=[]
                #print(x)
            s='frame'+str(x)+'.jpg'
                #print(s)
            gray=cv2.imread(s)

            cell_size=(8,8)
            block_size=(2,2)
            nbins=9


            winSize = (gray.shape[1] // cell_size[1] * cell_size[1],gray.shape[0] // cell_size[0] * cell_size[0])
            blockSize = (block_size[1] * cell_size[1],block_size[0] * cell_size[0])
            blockStride = (cell_size[1], cell_size[0])
            cellSize = (cell_size[1], cell_size[0])
            nbins = 9
            derivAperture = 1
            winSigma = -1.
            histogramNormType = 0
            L2HysThreshold = 0.2
            gammaCorrection = 1
            nlevels = 64
            signedGradients = True

            hog = cv2.HOGDescriptor(winSize,blockSize,blockStride,cellSize,nbins,derivAperture,winSigma,histogramNormType,L2HysThreshold,gammaCorrection,nlevels, signedGradients)

            n_cells = (gray.shape[0] // cell_size[0], gray.shape[1] // cell_size[1])
            hog_feats = hog.compute(gray).ravel()
            hog_lst=hog_feats.tolist()
            X.append(hog_lst)
            y.append(1)
for z in range(1,101):
    #print(z)
    if z%3!=0:
            #com_list=[]

        ss='C:\\Users\\ASUS\\Desktop\\violence_detection\\bin_nf\\ndata_'+str(z)
        os.chdir(ss)

        file_list = os.listdir(ss) 
        number_of_files = len(file_list)
            #print(str(z) + " --- "+str(number_of_files))
            #lst=random.sample(range(1,number_of_files), 31)
            #lst.sort()


        for x in range(1,number_of_files+1):
            res=[]
                #print(x)
            s='frame'+str(x)+'.jpg'
                #print(s)
            gray=cv2.imread(s)

            cell_size=(8,8)
            block_size=(2,2)
            nbins=9


            winSize = (gray.shape[1] // cell_size[1] * cell_size[1],gray.shape[0] // cell_size[0] * cell_size[0])
            blockSize = (block_size[1] * cell_size[1],block_size[0] * cell_size[0])
            blockStride = (cell_size[1], cell_size[0])
            cellSize = (cell_size[1], cell_size[0])
            nbins = 9
            derivAperture = 1
            winSigma = -1.
            histogramNormType = 0
            L2HysThreshold = 0.2
            gammaCorrection = 1
            nlevels = 64
            signedGradients = True

            hog = cv2.HOGDescriptor(winSize,blockSize,blockStride,cellSize,nbins,derivAperture,winSigma,histogramNormType,L2HysThreshold,gammaCorrection,nlevels, signedGradients)

            n_cells = (gray.shape[0] // cell_size[0], gray.shape[1] // cell_size[1])
            hog_feats = hog.compute(gray).ravel()
            hog_lst=hog_feats.tolist()
            X.append(hog_lst)
            y.append(0)
print('Videos are processed!')
c =list( zip(X,y))
random.shuffle(c)
X = [i[0] for i in c]
y = [i[1] for i in c]
print('Training the model')
    
clf = svm.SVC(gamma='auto')
clf.fit(X, y)

print('Model training finished')

             
def onclick3(self):
    print("Video Number...............Expected result.........Experimental result")
    tmp1 = str(eval(inp1.get()))
    tmp2 = str(eval(inp2.get()))
    fr = int(tmp1)
    to = int(tmp2)
    acc=0
    tot=0
    for z in range(fr,to):
        #print(z)
        if z%5==0:
            tot=tot+1
            #com_list=[]

            ss='C:\\Users\\ASUS\\Desktop\\violence_detection\\bin_f\\data_'+str(z)
            os.chdir(ss)

            file_list = os.listdir(ss) 
            number_of_files = len(file_list)
            #print(str(z) + " --- "+str(number_of_files))
            #lst=random.sample(range(1,number_of_files), 31)
            #lst.sort()

            cnt=0
            for x in range(1,number_of_files+1):
                res=[]
                #print(x)
                s='frame'+str(x)+'.jpg'
                #print(s)
                gray=cv2.imread(s)

                cell_size=(8,8)
                block_size=(2,2)
                nbins=9


                winSize = (gray.shape[1] // cell_size[1] * cell_size[1],gray.shape[0] // cell_size[0] * cell_size[0])
                blockSize = (block_size[1] * cell_size[1],block_size[0] * cell_size[0])
                blockStride = (cell_size[1], cell_size[0])
                cellSize = (cell_size[1], cell_size[0])
                nbins = 9
                derivAperture = 1
                winSigma = -1.
                histogramNormType = 0
                L2HysThreshold = 0.2
                gammaCorrection = 1
                nlevels = 64
                signedGradients = True

                hog = cv2.HOGDescriptor(winSize,blockSize,blockStride,cellSize,nbins,derivAperture,winSigma,histogramNormType,L2HysThreshold,gammaCorrection,nlevels, signedGradients)

                n_cells = (gray.shape[0] // cell_size[0], gray.shape[1] // cell_size[1])
                hog_feats = hog.compute(gray).ravel()
                hog_lst=hog_feats.tolist()
                rs=clf.predict([hog_lst])

                if rs[0]==1:
                    cnt=cnt+1;
                        #print(cnt)
            #print(cnt)
            
            if cnt>(number_of_files/2):
                acc=acc+1
                print(str(z)+".........................fight....................."+"fight")
                
            else:
                print(str(z)+".........................fight....................."+"non fight")



    for z in range(fr,to):
        #print(z)
        if z%5==0:
            tot=tot+1
            #com_list=[]

            ss='C:\\Users\\ASUS\\Desktop\\violence_detection\\bin_nf\\ndata_'+str(z)
            os.chdir(ss)

            file_list = os.listdir(ss) 
            number_of_files = len(file_list)
            #print(str(z) + " --- "+str(number_of_files))
            #lst=random.sample(range(1,number_of_files), 31)
            #lst.sort()

            cnt=0
            for x in range(1,number_of_files+1):
                res=[]
                #print(x)
                s='frame'+str(x)+'.jpg'
                #print(s)
                gray=cv2.imread(s)

                cell_size=(8,8)
                block_size=(2,2)
                nbins=9


                winSize = (gray.shape[1] // cell_size[1] * cell_size[1],gray.shape[0] // cell_size[0] * cell_size[0])
                blockSize = (block_size[1] * cell_size[1],block_size[0] * cell_size[0])
                blockStride = (cell_size[1], cell_size[0])
                cellSize = (cell_size[1], cell_size[0])
                nbins = 9
                derivAperture = 1
                winSigma = -1.
                histogramNormType = 0
                L2HysThreshold = 0.2
                gammaCorrection = 1
                nlevels = 64
                signedGradients = True

                hog = cv2.HOGDescriptor(winSize,blockSize,blockStride,cellSize,nbins,derivAperture,winSigma,histogramNormType,L2HysThreshold,gammaCorrection,nlevels, signedGradients)

                n_cells = (gray.shape[0] // cell_size[0], gray.shape[1] // cell_size[1])
                hog_feats = hog.compute(gray).ravel()
                hog_lst=hog_feats.tolist()
                rs=clf.predict([hog_lst])
                if rs[0]==1:
                    cnt=cnt+1;
                        #print(cnt)
            #print(cnt)
            if cnt>(number_of_files/2):
                print(str(z)+".........................non fight................."+"fight")
            else:
                acc=acc+1
                print(str(z)+".........................non fight................."+"non fight")

    acuracy=(acc/tot)*100
   
    print("Accuracy: "+str(acuracy)+" %")
    tmp3 = str(acuracy) + " %"
    lvl10.configure(text=tmp3)
    #print(acuracy)
    #finalllll


root.geometry("600x500")
root.configure(bg='#151313')

topFrame = Frame(root)
topFrame.configure(bg='#151313')

lvl55 = Label(root, text="Training Completed")
lvl55.pack(pady=5)


topFrame.pack(pady=20)


lvl6 = Label(root, text="Input video range")
lvl6.pack(pady=5)

bottomFrame = Frame(root)


table2 = LabelFrame(bottomFrame)

lvl7 = Label(table2, text="Form")
lvl8 = Label(table2, text="TO")
inp1 = Entry(table2)
inp2 = Entry(table2)

lvl7.grid(row=0, sticky=W)
lvl8.grid(row=1, sticky=W)
inp1.grid(row=0, column=1)
inp2.grid(row=1, column=1)
table2.pack(pady=5)

btn2 = Button(bottomFrame, text="Run", bg='#070334', fg="white", padx=30)
btn2.bind("<Button-1>", onclick3)
btn2.pack(pady=5)
table3 = Frame(bottomFrame)
lvl9 = Label(table3, text="Accuracy")
lvl10 = Label(table3, text="----------")

lvl9.grid(row=0, sticky=W)
lvl10.grid(row=0, column=1)
table3.pack(pady=5)
bottomFrame.configure(bg='#151313')
bottomFrame.pack(pady=5)

root.mainloop()
# Out:
# Videos are processing!
# Videos are processed!
# Training the model
# Model training finished
# Video Number...............Expected result.........Experimental result
# 5.........................fight.....................fight
# 10.........................fight.....................fight
# 15.........................fight.....................fight
# 20.........................fight.....................fight
# 25.........................fight.....................fight
# 30.........................fight.....................fight
# 35.........................fight.....................fight
# 40.........................fight.....................fight
# 45.........................fight.....................fight
# 50.........................fight.....................fight
# 55.........................fight.....................fight
# 60.........................fight.....................fight
# 65.........................fight.....................fight
# 70.........................fight.....................fight
# 75.........................fight.....................fight
# 80.........................fight.....................fight
# 85.........................fight.....................fight
# 90.........................fight.....................fight
# 95.........................fight.....................fight
# 5.........................non fight.................non fight
# 10.........................non fight.................non fight
# 15.........................non fight.................non fight
# 20.........................non fight.................non fight
# 25.........................non fight.................non fight
# 30.........................non fight.................non fight
# 35.........................non fight.................non fight
# 40.........................non fight.................fight
# 45.........................non fight.................non fight
# 50.........................non fight.................non fight
# 55.........................non fight.................non fight
# 60.........................non fight.................fight
# 65.........................non fight.................non fight
# 70.........................non fight.................non fight
# 75.........................non fight.................non fight
# 80.........................non fight.................non fight
# 85.........................non fight.................non fight
# 90.........................non fight.................non fight
# 95.........................non fight.................non fight
# Accuracy: 94.73684210526315 %

# %%
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
from sklearn.model_selection import cross_val_score
from sklearn import svm
from sklearn.metrics import accuracy_score
clf = svm.SVC(gamma='auto',kernel='linear')
clf = clf.fit(X_train1, y_train)
y_pred = clf.predict(X_test1)

print('Misclassified samples: %d' % (y_test != y_pred).sum())
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))

from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(y_test, y_pred)
# Out:
# Misclassified samples: 0
# Accuracy: 1.00
# 1.0

# %%
from sklearn import svm
clf = svm.SVC(gamma='auto',kernel='rbf')
clf = clf.fit(X_train1, y_train)
y_pred = clf.predict(X_test1)
print('Misclassified samples: %d' % (y_test != y_pred).sum())
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))

from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(y_test, y_pred)
# Out:
# Misclassified samples: 51
# Accuracy: 0.98
# [[1389   51]
#  [   0 1408]]
# 0.9648139146379018

# %%
from sklearn import svm
clf = svm.SVC(gamma='auto',kernel='poly')
clf = clf.fit(X_train1, y_train)
y_pred = clf.predict(X_test1)
print('Misclassified samples: %d' % (y_test != y_pred).sum())
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))

from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(y_test, y_pred)
# Out:
# Misclassified samples: 1408
# Accuracy: 0.51
# [[1440    0]
#  [1408    0]]
# C:\Users\Asus\Anaconda3\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:538: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# 0.0

# %%
from sklearn import svm
clf = svm.SVC(gamma='auto',kernel='sigmoid')
clf = clf.fit(X_train1, y_train)
y_pred = clf.predict(X_test1)
print('Misclassified samples: %d' % (y_test != y_pred).sum())
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))

from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(y_test, y_pred)
# Out:
# Misclassified samples: 63
# Accuracy: 0.98
# [[1377   63]
#  [   0 1408]]
# 0.9567108848545544

# %%
from sklearn.linear_model import LogisticRegression

ppn = LogisticRegression(random_state=1)
ppn = ppn.fit(X_train1, y_train)
y_pred = ppn.predict(X_test1)
print('Misclassified samples: %d' % (y_test != y_pred).sum())
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))

from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(y_test, y_pred)
# Out:
# Misclassified samples: 1
# Accuracy: 1.00
# [[1439    1]
#  [   0 1408]]
# 0.9992979161446027

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X_train1, y_train)
y_pred = clf.predict(X_test1)
print('Misclassified samples: %d' % (y_test != y_pred).sum())
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))

from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(y_test, y_pred)
# Out:
# Misclassified samples: 1
# Accuracy: 1.00
# [[1439    1]
#  [   0 1408]]
# 0.9992979161446027

# %%
import sklearn
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
clf = LDA()
clf.fit(X_train1, y_train)
y_pred = clf.predict(X_test1)
print('Misclassified samples: %d' % (y_test != y_pred).sum())
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))

from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(y_test, y_pred)
# Out:
# Misclassified samples: 0
# Accuracy: 1.00
# [[1440    0]
#  [   0 1408]]
# 1.0

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred = gnb.fit(X_train1, y_train).predict(X_test1)
print('Misclassified samples: %d' % (y_test != y_pred).sum())
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(y_test, y_pred)
# Out:
# Misclassified samples: 83
# Accuracy: 0.97
# 0.9433463718201924

# %%
from sklearn.neural_network import MLPClassifier
gnb = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(13, 2), random_state=1)
y_pred = gnb.fit(X_train1, y_train).predict(X_test1)
print('Misclassified samples: %d' % (y_test != y_pred).sum())
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))

from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(y_test, y_pred)
# Out:
# Misclassified samples: 2
# Accuracy: 1.00
# [[1440    0]
#  [   2 1406]]
# 0.9985962913108558

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
y_pred = neigh.fit(X_train1, y_train).predict(X_test1)
print('Misclassified samples: %d' % (y_test != y_pred).sum())
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))

from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
from sklearn.metrics import matthews_corrcoef
matthews_corrcoef(y_test, y_pred)
# Out:
# Misclassified samples: 0
# Accuracy: 1.00
# [[1440    0]
#  [   0 1408]]
# 1.0
